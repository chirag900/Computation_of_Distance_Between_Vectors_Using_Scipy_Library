# %% [markdown]
# Manhattan_distance

# %%
import scipy.spatial
import numpy as np

a = np.array([1,2])
b = np.array([3,4])

# %%
a,b
# Out:
# (array([1, 2]), array([3, 4]))

# %%
manhattan_distance = scipy.spatial.distance.cityblock(a, b)

# %%
print(manhattan_distance)
# Out:
# 4

# %%
x = np.array([3,6,8])
y = np.array([10,12,18])

# %%
x,y
# Out:
# (array([3, 6, 8]), array([10, 12, 18]))

# %%
mahattan_dist1 = scipy.spatial.distance.cityblock(x,y)

# %%
mahattan_dist1
# Out:
# 23

# %% [markdown]
# ![Manhattan_Distance_Scipy_Document.PNG](attachment:Manhattan_Distance_Scipy_Document.PNG)
